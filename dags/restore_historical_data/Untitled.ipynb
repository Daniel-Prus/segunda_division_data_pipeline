# %%
import pandas as pd
import numpy as np
raw_data_test = pd.read_csv('raw_data_test.csv')

# %%
raw_data_test.loc[1777:, ['goals.home', 'goals.away']]= np.nan

# %%
len(raw_data_test)
# Out:
# 1868

# %%
raw_data_test.tail(30)
# Out:
#       fixture.id      fixture.referee fixture.timezone  \
# 1838      721696       Eduardo Prieto              UTC
# 1839      721697      Daniel Trujillo              UTC
# 1840      721698          Iosu Galech              UTC
# 1841      721699     Dámaso Arcediano              UTC
# 1842      721700        Álvaro Moreno              UTC
# 1843      721701        Raúl González              UTC
# 1844      721702        Víctor García              UTC
# 1845      721703         Rubén Ávalos              UTC
# 1846      721704      Javier Iglesias              UTC
# 1847      721705         Gorka Sagues              UTC
# 1848      721706   Alejandro Quintero              UTC
# 1849      721707           José López              UTC
# 1850      721708             Saúl Ais              UTC
# 1851      721709         Jon González              UTC
# 1852      721710           Luis Milla              UTC
# 1853      721711          Juan Pulido              UTC
# ...

# %%
len(raw_data['fixture.periods.first'].notnull())
# Out:
# 1868

# %%
np.isnan(raw_data['fixture.periods.first'][max(raw_data.index)])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8876/3766304156.py in <module>
# ----> 1 np.isnan(raw_data['fixture.periods.first'][-1])
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ...

# %%
max(raw_data.index)
# Out:
# 1867

# %%
lala = range(0,44)

# %%
lala
# Out:
# range(0, 44)

# %%
np.isnan(raw_data['fixture.periods.first'][min(raw_data.index)])
# Out:
# False

# %%
raw_data_test.drop(columns='fixture.referee', inplace=True)

# %%
raw_data_test.sort_values(by='fixture.date', inplace=True )

# %%
raw_data_test
# Out:
#       fixture.id fixture.timezone               fixture.date  \
# 2          27521              UTC  2018-08-17T18:00:00+00:00
# 0          27519              UTC  2018-08-17T20:00:00+00:00
# 4          27523              UTC  2018-08-18T17:00:00+00:00
# 7          27526              UTC  2018-08-18T17:30:00+00:00
# 1          27520              UTC  2018-08-18T18:30:00+00:00
# 3          27522              UTC  2018-08-18T20:00:00+00:00
# 8          27527              UTC  2018-08-19T17:00:00+00:00
# 9          27528              UTC  2018-08-19T17:00:00+00:00
# 10         27529              UTC  2018-08-19T18:30:00+00:00
# 6          27525              UTC  2018-08-19T20:00:00+00:00
# 5          27524              UTC  2018-08-20T18:00:00+00:00
# 13         27532              UTC  2018-08-24T20:00:00+00:00
# 16         27535              UTC  2018-08-24T20:00:00+00:00
# 20         27539              UTC  2018-08-25T17:00:00+00:00
# ...
